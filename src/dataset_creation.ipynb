# %%
import numpy as np

from generate_data import create_dataset

# %%
# --- Dataset Generation ---
SCENARIO_NAMES = ["city_6_miami"]
BS_IDXS = [1, 2, 3]
N_SAMPLES = 500
N_USERS = 4

PATCH_ROWS = 16
PATCH_COLS = 1

P_TOTAL = 1.0
SIGMA2 = 1e-3

SAVE = True

if SAVE:
    import os
    from faker import Faker
    
    DATA_DIR = "data/sim_" + "_".join(SCENARIO_NAMES) + f"_{Faker("de_DE").city().lower()}"

all_tokens_tensor, all_channels_array = create_dataset(scenario_names=SCENARIO_NAMES,
                                                       bs_idxs=BS_IDXS,
                                                       n_samples=N_SAMPLES,
                                                       n_users=N_USERS,
                                                       patch_rows=PATCH_ROWS,
                                                       patch_cols=PATCH_COLS)

_, N, _, M = all_channels_array.shape
# Out:
# Generating data for 3 scenario-BS pairs...
# Data Generation:   0%|          | 0/3 [00:00<?, ?it/s]
# Basestation 1
#
# UE-BS Channels
# Reading ray-tracing: 100%|██████████| 42984/42984 [00:00<00:00, 151143.30it/s]
# Generating channels: 100%|██████████| 42984/42984 [00:03<00:00, 13667.58it/s]
# Data Generation:  33%|███▎      | 1/3 [00:04<00:09,  4.64s/it]
# Basestation 2
#
# UE-BS Channels
# Reading ray-tracing: 100%|██████████| 42984/42984 [00:00<00:00, 143714.84it/s]
# Generating channels: 100%|██████████| 42984/42984 [00:02<00:00, 14575.16it/s]
# Data Generation:  67%|██████▋   | 2/3 [00:09<00:04,  4.61s/it]
# Basestation 3
#
# UE-BS Channels
# Reading ray-tracing: 100%|██████████| 42984/42984 [00:00<00:00, 126277.81it/s]
# Generating channels: 100%|██████████| 42984/42984 [00:03<00:00, 11455.74it/s]
# Data Generation: 100%|██████████| 3/3 [00:14<00:00,  4.85s/it]
# Sampling: 100%|██████████| 500/500 [00:00<00:00, 4196.02it/s]
# Preparing data: 100%|██████████| 500/500 [00:00<00:00, 2374.17it/s]

# %%
if SAVE:

    if not os.path.exists(f"../{DATA_DIR}"):
        os.makedirs(f"../{DATA_DIR}")
        
    np.save(f"../{DATA_DIR}/channels.npy", all_channels_array)

    parameters = {
        "scenario_names": SCENARIO_NAMES,
        "bs_idxs": BS_IDXS,
        "samples": N_SAMPLES,
        "users": N_USERS,
        "subcarriers": N,
        "bs_antennas": M,
        "p_total": P_TOTAL,
        "sigma2": SIGMA2,
        # "patch_rows": PATCH_ROWS,
        # "patch_cols": PATCH_COLS
    }

    with open(f"../{DATA_DIR}/parameters.txt", "w") as f:
        for key, value in parameters.items():
            f.writelines(f"{key}: {value}\n")
